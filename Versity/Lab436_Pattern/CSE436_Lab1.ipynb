# %% [markdown]
# # **PYTHON Syntax**

# %% [markdown]
# ### Ex1: Insert the missing part of the code below to output "Hello World".

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Ex2: Complete the code block, print "YES" if 5 is larger than 2.
#
# ### Hint: remember the indentation.

# %%
if 5 > 2:
    print("YES")
# Out:
# YES

# %% [markdown]
# # **PYTHON Comments**

# %% [markdown]
# ### Ex1: Comments in Python are written with a special character, which one?

# %%
#This is a comment

# %% [markdown]
# ### Ex2: Use a multiline string to make the a multiline comment:

# %%
"""
This is a comment
written in
more than just one line
"""
# Out:
# '\nThis is a comment\nwritten in\nmore than just one line\n'

# %% [markdown]
# # **PYTHON Variables**

# %% [markdown]
# ### Ex1: Create a variable named carname and assign the value Volvo to it.

# %%
carname = "Volvo"

# %% [markdown]
# ### Ex2: Create a variable named x and assign the value 50 to it.

# %%
x = 50

# %% [markdown]
# ### Ex3: Display the sum of 5 + 10, using two variables: x and y.

# %%
x = 5
y = 10
print(x+y)
# Out:
# 15

# %% [markdown]
# ### Ex4: Create a variable called z, assign x + y to it, and display the result.

# %%
x = 5
y = 10
z = x+y
print(z)
# Out:
# 15

# %% [markdown]
# ### Ex5: Insert the correct syntax to assign values to multiple variables in one line:

# %%
x, y, z = "Orange", "Banana", "Cherry"

# %% [markdown]
# ### Ex6: Insert the correct syntax to assign the same value to all three variables in one code line.

# %%
x = y = z = "Orange"

# %% [markdown]
# ### Ex7: Insert the correct keyword to make the variable x belong to the global scope.

# %%
def myfunc():
    global x
    x = "fantastic"

# %% [markdown]
# # **PYTHON Data Types**

# %% [markdown]
# ### Ex1: The following code example would print the data type of x, what data type would that be?

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ### Ex2: The following code example would print the data type of x, what data type would that be?

# %%
x = "Hello World"
print(type(x))
# Out:
# <class 'str'>

# %% [markdown]
# ### Ex3: The following code example would print the data type of x, what data type would that be?

# %%
x = 20.5
print(type(x))
# Out:
# <class 'float'>

# %% [markdown]
# ### Ex4: The following code example would print the data type of x, what data type would that be?

# %%
x = ["apple", "banana", "cherry"]
print(type(x))
# Out:
# <class 'list'>

# %% [markdown]
# ### Ex5: The following code example would print the data type of x, what data type would that be?

# %%
x = ("apple", "banana", "cherry")
print(type(x))
# Out:
# <class 'tuple'>

# %% [markdown]
# ### Ex6: The following code example would print the data type of x, what data type would that be?

# %%
x = {"name" : "John", "age" : 36}
print(type(x))
# Out:
# <class 'dict'>

# %% [markdown]
# ### Ex7: The following code example would print the data type of x, what data type would that be?

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %% [markdown]
# # **PYTHON Numbers**

# %% [markdown]
# ### Ex1: Insert the correct syntax to convert x into a floating point number.

# %%
x = 5
x = float(x)

# %% [markdown]
# ### Ex2: Insert the correct syntax to convert x into a integer.

# %%
x = 5.5
x = int(x)

# %% [markdown]
# ### Ex3: Insert the correct syntax to convert x into a complex number.

# %%
x = 5
x = complex(x)

# %% [markdown]
# # **PYTHON Strings**

# %% [markdown]
# ### Ex1: Use the len function to print the length of the string.

# %%
x = "Hello World"
print(len(x))
# Out:
# 11

# %% [markdown]
# ### Ex2: Get the first character of the string txt.

# %%
txt = "Hello World"
x = txt[0]
print(x)
# Out:
# H

# %% [markdown]
# ### Ex3: Get the characters from index 2 to index 4 (llo).

# %%
txt = "Hello World"
x = txt[2:5]
print(x)
# Out:
# llo

# %% [markdown]
# ### Ex4: Return the string without any whitespace at the beginning or the end.

# %%
txt = " Hello World "
x = txt.strip()

# %% [markdown]
# ### Ex5: Convert the value of txt to upper case.

# %%
txt = "Hello World"
txt = txt.upper()
print(txt)
# Out:
# HELLO WORLD

# %% [markdown]
# ### Ex6: Convert the value of txt to lower case.

# %%
txt = "Hello World"
txt = txt.lower()
print(txt)
# Out:
# hello world

# %% [markdown]
# ### Ex7: Replace the character H with a J.

# %%
txt = "Hello World"
txt = txt.replace("H", "J")
print(txt)
# Out:
# Jello World

# %% [markdown]
# ### Ex8: Insert the correct syntax to add a placeholder for the age parameter.

# %%
age = 36
txt = "My name is John, and I am {}"
print(txt.format(age))
# Out:
# My name is John, and I am 36

# %% [markdown]
# # **PYTHON Booleans**

# %% [markdown]
# ### Ex1: The statement below would print a Boolean value, which one?

# %%
print(10 > 9)
# Out:
# True

# %% [markdown]
# ### Ex2: The statement below would print a Boolean value, which one?

# %%
print(10 == 9)
# Out:
# False

# %% [markdown]
# ### Ex3: The statement below would print a Boolean value, which one?

# %%
print(10 < 9)
# Out:
# False

# %% [markdown]
# ### Ex4: The statement below would print a Boolean value, which one?

# %%
print(bool("abc"))
# Out:
# True

# %% [markdown]
# ### Ex5: The statement below would print a Boolean value, which one?

# %%
print(bool(0))
# Out:
# False

# %% [markdown]
# # **PYTHON Operators**

# %% [markdown]
# ### Ex1: Multiply 10 with 5, and print the result.

# %%
print(10 * 5)
# Out:
# 50

# %% [markdown]
# ### Ex2: Divide 10 by 2, and print the result.

# %%
print(10 / 2)
# Out:
# 5.0

# %% [markdown]
# ### Ex3: Use the correct membership operator to check if "apple" is present in the fruits object.

# %%
fruits = ["apple", "banana"]
if "apple" in fruits:
    print("Yes, apple is a fruit")
# Out:
# Yes, apple is a fruit

# %% [markdown]
# ### Ex4: Use the correct comparison operator to check if 5 is not equal to 10.

# %%
if 5 != 10:
  print("5 and 10 is not equal")
# Out:
# 5 and 10 is not equal

# %% [markdown]
# ### Ex5: Use the correct logical operator to check if at least one of two statements is True.

# %%
if 5 == 10 or 4 == 4:
    print("At least one of the statements is true")
# Out:
# At least one of the statements is true

# %% [markdown]
# # **PYTHON Lists**

# %% [markdown]
# ### Ex1: Print the second item in the fruits list.

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[1])
# Out:
# banana

# %% [markdown]
# ### Ex2: Change the value from "apple" to "kiwi", in the fruits list.

# %%
fruits = ["apple", "banana", "cherry"]
fruits[0] = "kiwi"
print(fruits[0])
# Out:
# kiwi

# %% [markdown]
# ### Ex3: Use the append method to add "orange" to the fruits list.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ### Ex4: Use the insert method to add "lemon" as the second item in the fruits list.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.insert(1, "lemon")
print(fruits)
# Out:
# ['apple', 'lemon', 'banana', 'cherry']

# %% [markdown]
# ### Ex5: Use the remove method to remove "banana" from the fruits list.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ### Ex6: Use negative indexing to print the last item in the list.

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[-1])
# Out:
# cherry

# %% [markdown]
# ### Ex7: Use a range of indexes to print the third, fourth, and fifth item in the list.

# %%
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruits[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %% [markdown]
# ### Ex8: Use the correct syntax to print the number of items in the list.

# %%
fruits = ["apple", "banana", "cherry"]
print(len(fruits))
# Out:
# 3

# %% [markdown]
# # **PYTHON Tuples**

# %% [markdown]
# ### Ex1: Use the correct syntax to print the first item in the fruits tuple.

# %%
fruits = ("apple", "banana", "cherry")
print(fruits[0])
# Out:
# apple

# %% [markdown]
# ### Ex2: Use the correct syntax to print the number of items in the fruits tuple.

# %%
fruits = ("apple", "banana", "cherry")
print(len(fruits))
# Out:
# 3

# %% [markdown]
# ### Ex3: Use negative indexing to print the last item in the tuple.

# %%
fruits = ("apple", "banana", "cherry")
print(fruits[-1])
# Out:
# cherry

# %% [markdown]
# ### Ex4: Use a range of indexes to print the third, fourth, and fifth item in the tuple.

# %%
fruits = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(fruits[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %% [markdown]
# # **PYTHON Sets**

# %% [markdown]
# ### Ex1: Check if "apple" is present in the fruits set.

# %%
fruits = {"apple", "banana", "cherry"}
if "apple" in fruits:
  print("Yes, apple is a fruit!")
# Out:
# Yes, apple is a fruit!

# %% [markdown]
# ### Ex2: Use the add method to add "orange" to the fruits set.

# %%
fruits = {"apple", "banana", "cherry"}
fruits.add("orange")
print(fruits)
# Out:
# {'cherry', 'orange', 'banana', 'apple'}

# %% [markdown]
# ### Ex3: Use the correct method to add multiple items (more_fruits) to the fruits set.

# %%
fruits = {"apple", "banana", "cherry"}
more_fruits = ["orange", "mango", "grapes"]
fruits.update(more_fruits)
print(fruits)
# Out:
# {'cherry', 'apple', 'orange', 'banana', 'grapes', 'mango'}

# %% [markdown]
# ### Ex4: Use the remove method to remove "banana" from the fruits set.

# %%
fruits = {"apple", "banana", "cherry"}
fruits.remove("banana")
print(fruits)
# Out:
# {'cherry', 'apple'}

# %% [markdown]
# ### Ex5: Use the discard method to remove "banana" from the fruits set.

# %%
fruits = {"apple", "banana", "cherry"}
fruits.discard("banana")
print(fruits)
# Out:
# {'cherry', 'apple'}

# %% [markdown]
# # **PYTHON Dictionaries**

# %% [markdown]
# ### Ex1: Use the get method to print the value of the "model" key of the car dictionary.

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(car.get("model"))
# Out:
# Mustang

# %% [markdown]
# ### Ex2: Change the "year" value from 1964 to 2020.

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car["year"] = 2020
print(car.get("year"))
# Out:
# 2020

# %% [markdown]
# ### Ex3: Add the key/value pair "color" : "red" to the car dictionary.

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car["color"] = "red"
print(car.get("color"))
# Out:
# red

# %% [markdown]
# ### Ex4: Use the pop method to remove "model" from the car dictionary.

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car.pop("model")
print(car.get("model"))
# Out:
# None

# %% [markdown]
# ### Ex5: Use the clear method to empty the car dictionary.

# %%
car =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
car.clear()
print(car)
# Out:
# {}

# %% [markdown]
# # **PYTHON If...Else**

# %% [markdown]
# ### Ex1: Print "Hello World" if a is greater than b.

# %%
a = 50
b = 10
if a > b:
  print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Ex2: Print "Hello World" if a is not equal to b.

# %%
a = 50
b = 10
if a != b:
    print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Ex3: Print "Yes" if a is equal to b, otherwise print "No".

# %%
a = 50
b = 10
if a == b:
  print("Yes")
else:
  print("No")
# Out:
# No

# %% [markdown]
# ### Ex4: Print "1" if a is equal to b, print "2" if a is greater than b, otherwise print "3".

# %%
a = 50
b = 50
if a == b:
  print("1")
elif a > b:
  print("2")
else:
  print("3")
# Out:
# 1

# %% [markdown]
# ### Ex5: Print "Hello" if a is equal to b, and c is equal to d.

# %%
c = 5
d = 5
if a == b and c == d:
  print("Hello")
# Out:
# Hello

# %% [markdown]
# ### Ex6: Print "Hello" if a is equal to b, or if c is equal to d.

# %%
if a == b or c == d:
  print("Hello")
# Out:
# Hello

# %% [markdown]
# ### Ex7: Complete the code block, print "YES" if 5 is larger than 2
#         Hint: remember the indentation.

# %%
if 5 > 2:
    print("YES")
# Out:
# YES

# %% [markdown]
# ### Ex8: Use the correct one line short hand syntax to print "YES" if a is equal to b, otherwise print("NO").

# %%
a = 2
b = 5
print("YES") if a == b else print("NO")
# Out:
# NO

# %% [markdown]
# ### Ex9: Use an if statement to print "YES" if either a or b is equal to c.

# %%
a = 2
b = 50
c = 2
if a == c or b == c:
  print("YES")
# Out:
# YES

# %% [markdown]
# # **PYTHON While Loops**

# %% [markdown]
# ### Ex1: Print i as long as i is less than 6.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Ex2: Stop the loop if i is 3.

# %%
i = 1
while i < 6:
    print(i)
    if i == 3:
        break
    i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### Ex3: In the loop, when i is 3, jump directly to the next iteration.

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# ### Ex4: Print a message once the condition is false.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %% [markdown]
# # **PYTHON Inheritance**

# %% [markdown]
# ### Ex1: What is the correct syntax to create a class named Student that will inherit properties and methods from a class named Person?

# %%
class Student(Person) :

# %% [markdown]
# ### Ex2: We have used the Student class to create an object named x. What is the correct syntax to execute the printname method of the object x?

# %%
 class Person:
  def __init__(self, fname):
    self.firstname = fname

  def printname(self):
    print(self.firstname)

 class Student(Person):
  pass

x = Student("Mike")
x.printname()

# %% [markdown]
# # **PYTHON Modules**

# %% [markdown]
# ### Ex1: What is the correct syntax to import a module named "mymodule"?

# %%
import mymodule

# %% [markdown]
# ### Ex2: If you want to refer to a module by using a different name, you can create an alias. What is the correct syntax for creating an alias for a module?

# %%
import mymodule as mx

# %% [markdown]
# ### Ex3: What is the correct syntax of printing all variables and function names of the "mymodule" module?

# %%
import mymodule

print(dir(mymodule))

# %% [markdown]
# ### Ex4: What is the correct syntax of importing only the person1 dictionary of the "mymodule" module?

# %%
from mymodule import person1
